# %%
require(ncdf4)
require(RNetCDF)
require(psych)
Sys.setenv(TZ="UTC")

# %%
folder<-paste("/Volumes/HELIOS/Data/Meteorological/SST_MODAS_NZ/data/", sep="")
filenames<-list.files(path=folder, pattern=NULL, full.names=FALSE, recursive=FALSE)

# %%
#Latitude and Longitude of SST pixel closest to site

#site <- 'NZSINR'
#sitelat<--41.875
#sitelon<-171.375

site <- 'NZSIBT'
sitelat<--43.5
sitelon<-172.75

# %%
for(i in 1:length(filenames)){
    nc<-nc_open(paste(folder, filenames[i], sep=""))
    lats<-nc$dim$lat$vals
    lons<-nc$dim$lon$vals
    
    times<-as.data.frame(nc$dim$time$vals)
    colnames(times)<-"Time"
    lt<-as.matrix(abs(lons-sitelon))
    ll<-as.matrix(abs(lats-sitelat))
    lt<-lt^2
    ll<-ll^2
    distance<-sqrt(lt %+% t(ll))
    pt<-match(min(distance),distance)
    xdim<-nrow(distance)
    xx<-pt%%xdim
    yy<-pt%/%xdim+1
    
    data<-ncvar_get(nc, nc$var[[1]], start=c(xx,yy,1), count=c(1,1,nrow(times)))
    
    data<-round(data, digits=2)
    print(lons[xx])
    print(lats[yy])

    times<-cbind(times, data)
    colnames(times)<-c("Time", "Temp")

    tunits<-nc$dim$time$units
    dates<-utcal.nc(tunits, times$Time)
    unix_units<-"seconds since 1970-1-1 00:00:0.0"
    times$Unix<-utinvcal.nc(unix_units, dates)
    DateConvert<-times$Unix
    class(DateConvert)<-"POSIXct"
    DateExtract<-as.POSIXlt(DateConvert)
    times$jday<-as.character(DateExtract, format="%j")
    times$jday<-as.numeric(times$jday)

    times<-times[,c("Unix", "jday", "Temp")]
    
    outfile<-paste("../data/", site, "/modas/", filenames[i], sep="")

    outfile<-gsub(".nc", paste(site, ".txt", sep=""), outfile)

    write.table(times, outfile, row.names=FALSE, col.names=TRUE, quote=FALSE, sep="\t")
    
    nc_close(nc)
}
# Out:
# [1] 172.75
# [1] -43.5
# [1] 172.75
# [1] -43.5
# [1] 172.75
# [1] -43.5
# [1] 172.75
# [1] -43.5
# [1] 172.75
# [1] -43.5
# [1] 172.75
# [1] -43.5
# [1] 172.75
# [1] -43.5
# [1] 172.75
# [1] -43.5
# [1] 172.75
# [1] -43.5
# [1] 172.75
# [1] -43.5
# [1] 172.75
# [1] -43.5
# [1] 172.75
# [1] -43.5
# [1] 172.75
# [1] -43.5
# [1] 172.75
# [1] -43.5
# [1] 172.75
# [1] -43.5
# [1] 172.75
# [1] -43.5
# [1] 172.75
# [1] -43.5

# %%
# Out:
# [1] 171.375
# [1] -41.875

# %%
times
# Out:
#     Unix      jday Temp
# 1   725846400  1   17.21
# 2   725932800  2   17.22
# 3   726019200  3   17.23
# 4   726105600  4   17.24
# 5   726192000  5   17.24
# 6   726278400  6   17.25
# 7   726364800  7   17.25
# 8   726451200  8   17.25
# 9   726537600  9   17.26
# 10  726624000 10   17.26
# 11  726710400 11   17.26
# 12  726796800 12   17.26
# 13  726883200 13   17.26
# 14  726969600 14   17.26
# 15  727056000 15   17.26
# 16  727142400 16   17.26
# 17  727228800 17   17.26
# 18  727315200 18   17.26
# 19  727401600 19   17.27
# 20  727488000 20   17.27
# 21  727574400 21   17.28
# 22  727660800 22   17.28
# 23  727747200 23   17.28
# 24  727833600 24   17.29
# 25  727920000 25   17.30
# 26  728006400 26   17.31
# 27  728092800 27   17.31
# 28  728179200 28   17.32
# 29  728265600 29   17.33
# 30  728352000 30   17.34
# ⋮   ⋮         ⋮    ⋮
# 336 754790400 336  14.30
# 337 754876800 337  14.34
# 338 754963200 338  14.37
# 339 755049600 339  14.41
# 340 755136000 340  14.45
# 341 755222400 341  14.49
# 342 755308800 342  14.53
# 343 755395200 343  14.57
# 344 755481600 344  14.61
# 345 755568000 345  14.65
# 346 755654400 346  14.68
# 347 755740800 347  14.72
# 348 755827200 348  14.75
# 349 755913600 349  14.78
# 350 756000000 350  14.81
# 351 756086400 351  14.85
# 352 756172800 352  14.88
# 353 756259200 353  14.92
# 354 756345600 354  14.96
# 355 756432000 355  15.01
# 356 756518400 356  15.06
# 357 756604800 357  15.11
# 358 756691200 358  15.16
# 359 756777600 359  15.21
# 360 756864000 360  15.27
# 361 756950400 361  15.32
# 362 757036800 362  15.38
# 363 757123200 363  15.44
# 364 757209600 364  15.50
# 365 757296000 365  15.56
